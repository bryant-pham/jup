# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('BRAZIL_CITIES.csv', delimiter=';')
print(data.describe())
# Out:
#            CAPITAL  IBGE_RES_POP  IBGE_RES_POP_BRAS  IBGE_RES_POP_ESTR  \
# count  5576.000000  5.568000e+03       5.568000e+03        5568.000000
# mean      0.004842  3.428459e+04       3.420705e+04          77.543642
# std       0.069423  2.030598e+05       2.014381e+05        1795.397085
# min       0.000000  8.050000e+02       8.050000e+02           0.000000
# 25%       0.000000  5.235750e+03       5.230750e+03           0.000000
# 50%       0.000000  1.093500e+04       1.093000e+04           0.000000
# 75%       0.000000  2.353975e+04       2.342100e+04          10.000000
# max       1.000000  1.125350e+07       1.113378e+07      119727.000000
#
#             IBGE_DU  IBGE_DU_URBAN  IBGE_DU_RURAL      IBGE_POP  \
# count  5.566000e+03   5.566000e+03    5495.000000  5.568000e+03
# mean   1.030530e+04   8.861382e+03    1462.570337  2.760219e+04
# std    6.475994e+04   6.435371e+04    1693.833786  1.859099e+05
# min    2.390000e+02   6.000000e+01       3.000000  1.740000e+02
# ...

# %%
gdp = data.GDP
population = data.IBGE_RES_POP.values
print(gdp)
print(population)
# plt.plot(population, gdp)
# Out:
# 0       687035889,61
# 1        74402691,05
# 2       329431359,90
# 3       235497106,59
# 4           73425,26
# 5        88277462,53
# 6        47088301,58
# 7        49544087,54
# 8           21954,56
# 9           83788,90
# 10       61102372,82
# 11       58523732,73
# 12       29986609,04
# 13          32536,26
# 14           9418,11
# 15       60141145,20
# 16       46659222,76
# 17        3697053,11
# 18       42131380,22
# 19       53974918,69
# 20       25837046,14
# 21       70296364,35
# 22       22203168,44
# 23       23003343,34
# 24       39782735,72
# 25        2969299,25
# 26       18469475,90
# 27          30593,86
# 28          13286,71
# 29       37315782,50
#             ...
# 5546           31,44
# 5547           31,15
# 5548           31,08
# 5549           30,93
# 5550           30,92
# 5551           30,81
# 5552           30,63
# 5553           30,10
# 5554           29,73
# 5555           29,57
# 5556           29,36
# 5557           29,16
# ...
